# %% [markdown]
# #### import dos pacotes necessários

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

pd.set_option('display.max_rows', 500)

# %% [markdown]
# #### import dos dados

# %%
# import dos dados em um df chamado df_papa
df_papa = pd.read_csv('papafrescaSimNao.csv', sep=';')

# %%
# formato do df criado
df_papa.shape
# Out:
# (20869, 23)

# %%
# verificando se há alguma resposta nula
df_papa.isna().sum()
# Out:
# TV                   0
# RADIO                0
# PRENSA               0
# INTERNET             0
# Lapapaessaludable    0
# Lapapadaenergia      0
# Lapapaengorda        0
# Lapapaeseconomica    0
# Vapor                0
# Sopa                 0
# Pure                 0
# Fritas               0
# Sudada               0
# Salada               0
# OtrasFormas          0
# SOPAS                0
# GRANOS               0
# CARNE                0
# HUEVOS               0
# ARROZ                0
# ENSALADA             0
# NADAONINGUNO         0
# OTROS                0
# dtype: int64

# %% [markdown]
# O conjunto de dados contém cerca de 21k entradas, e 23 colunas

# %%
# nome das colunas
df_papa.columns
# Out:
# Index(['TV', 'RADIO', 'PRENSA', 'INTERNET', 'Lapapaessaludable',
#        'Lapapadaenergia', 'Lapapaengorda', 'Lapapaeseconomica', 'Vapor',
#        'Sopa', 'Pure', 'Fritas', 'Sudada', 'Salada', 'OtrasFormas', 'SOPAS',
#        'GRANOS', 'CARNE', 'HUEVOS', 'ARROZ', 'ENSALADA', 'NADAONINGUNO',
#        'OTROS'],
#       dtype='object')

# %%
# view dos dados importados
df_papa.head()
# Out:
#     TV RADIO PRENSA INTERNET Lapapaessaludable Lapapadaenergia Lapapaengorda  \
# 0  Nao   Nao    Nao      Nao               Nao             Nao           Sim
# 1  Nao   Nao    Nao      Nao               Nao             Nao           Sim
# 2  Nao   Nao    Nao      Nao               Nao             Nao           Sim
# 3  Nao   Nao    Nao      Nao               Nao             Nao           Sim
# 4  Nao   Nao    Nao      Nao               Nao             Nao           Sim
#
#   Lapapaeseconomica Vapor Sopa  ... Salada OtrasFormas SOPAS GRANOS CARNE  \
# 0               Sim   Nao  Nao  ...    Nao         Nao   Nao    Nao   Sim
# 1               Sim   Nao  Nao  ...    Nao         Nao   Nao    Nao   Nao
# 2               Sim   Nao  Nao  ...    Nao         Sim   Nao    Nao   Nao
# 3               Sim   Nao  Nao  ...    Nao         Nao   Nao    Nao   Nao
# 4               Sim   Nao  Nao  ...    Sim         Nao   Nao    Nao   Sim
#
#   HUEVOS ARROZ ENSALADA NADAONINGUNO OTROS
# 0    Nao   Sim      Nao          Nao   Nao
# 1    Nao   Sim      Nao          Nao   Sim
# 2    Nao   Nao      Nao          Sim   Nao
# 3    Nao   Sim      Nao          Nao   Sim
# 4    Nao   Sim      Nao          Nao   Nao
#
# [5 rows x 23 columns]

# %%
# vamos entender as proporções de cada resposta no df
for col in df_papa.columns:
    print('\n\n ---------{}---------'.format(col))
    print(df_papa[col].value_counts(normalize=True))
# Out:
#  ---------TV---------
# Nao    0.612679
# Sim    0.387321
# Name: TV, dtype: float64
#
#
#  ---------RADIO---------
# Nao    0.983564
# Sim    0.016436
# Name: RADIO, dtype: float64
#
#
#  ---------PRENSA---------
# Nao    0.996406
# Sim    0.003594
# Name: PRENSA, dtype: float64
#
#
#  ---------INTERNET---------
# Nao    0.976233
# Sim    0.023767
# Name: INTERNET, dtype: float64
#
#
#  ---------Lapapaessaludable---------
# Nao    0.720734
# Sim    0.279266
# Name: Lapapaessaludable, dtype: float64
#
#
#  ---------Lapapadaenergia---------
# Nao    0.87618
# Sim    0.12382
# Name: Lapapadaenergia, dtype: float64
#
#
#  ---------Lapapaengorda---------
# Nao    0.571422
# Sim    0.428578
# Name: Lapapaengorda, dtype: float64
#
#
#  ---------Lapapaeseconomica---------
# Sim    0.731803
# Nao    0.268197
# Name: Lapapaeseconomica, dtype: float64
#
#
#  ---------Vapor---------
# Nao    0.905075
# Sim    0.094925
# Name: Vapor, dtype: float64
#
#
#  ---------Sopa---------
# Nao    0.597441
# Sim    0.402559
# Name: Sopa, dtype: float64
#
#
#  ---------Pure---------
# Nao    0.932196
# Sim    0.067804
# Name: Pure, dtype: float64
#
#
#  ---------Fritas---------
# Nao    0.809957
# Sim    0.190043
# Name: Fritas, dtype: float64
#
#
#  ---------Sudada---------
# Nao    0.837702
# Sim    0.162298
# Name: Sudada, dtype: float64
#
#
#  ---------Salada---------
# Nao    0.935215
# Sim    0.064785
# Name: Salada, dtype: float64
#
#
#  ---------OtrasFormas---------
# Nao    0.946524
# Sim    0.053476
# Name: OtrasFormas, dtype: float64
#
#
#  ---------SOPAS---------
# Nao    0.916287
# Sim    0.083713
# Name: SOPAS, dtype: float64
#
#
#  ---------GRANOS---------
# Nao    0.906895
# Sim    0.093105
# Name: GRANOS, dtype: float64
#
#
#  ---------CARNE---------
# Sim    0.555225
# Nao    0.444775
# Name: CARNE, dtype: float64
#
#
#  ---------HUEVOS---------
# Nao    0.906847
# Sim    0.093153
# Name: HUEVOS, dtype: float64
#
#
#  ---------ARROZ---------
# Sim    0.609612
# Nao    0.390388
# Name: ARROZ, dtype: float64
#
#
#  ---------ENSALADA---------
# Nao    0.754804
# Sim    0.245196
# Name: ENSALADA, dtype: float64
#
#
#  ---------NADAONINGUNO---------
# Nao    0.980306
# Sim    0.019694
# Name: NADAONINGUNO, dtype: float64
#
#
#  ---------OTROS---------
# Nao    0.778331
# Sim    0.221669
# Name: OTROS, dtype: float64

# %% [markdown]
# - Vemos que a grande maioria das respostas é não
# - Todas as colunas têm somente a informação Sim ou Não

# %% [markdown]
# #### Transformação dos dados

# %%
# como todas as respostas são Sim ou Não, podemos transformar os dados em binário no df_papa 

for col in df_papa.columns:
    df_papa[col] = df_papa[col].apply(lambda x: True if x=='Sim' else False)
    
df_papa.head()
# Out:
#       TV  RADIO  PRENSA  INTERNET  Lapapaessaludable  Lapapadaenergia  \
# 0  False  False   False     False              False            False
# 1  False  False   False     False              False            False
# 2  False  False   False     False              False            False
# 3  False  False   False     False              False            False
# 4  False  False   False     False              False            False
#
#    Lapapaengorda  Lapapaeseconomica  Vapor   Sopa  ...  Salada  OtrasFormas  \
# 0           True               True  False  False  ...   False        False
# 1           True               True  False  False  ...   False        False
# 2           True               True  False  False  ...   False         True
# 3           True               True  False  False  ...   False        False
# 4           True               True  False  False  ...    True        False
#
#    SOPAS  GRANOS  CARNE  HUEVOS  ARROZ  ENSALADA  NADAONINGUNO  OTROS
# 0  False   False   True   False   True     False         False  False
# 1  False   False  False   False   True     False         False   True
# 2  False   False  False   False  False     False          True  False
# 3  False   False  False   False   True     False         False   True
# 4  False   False   True   False   True     False         False  False
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Aplicação do A Priori

# %% [markdown]
# Neste ponto vale destacar que um suporte muito baixo dá uma quantidade muito alta de combinações, e os *insights* obtidos não serão de grande valor, pois representam poucos casos do total. Assim, optaremos por um **suporte mínimo de 10%**.

# %%
# Como todos os dados do df são binários, podemos aplicar o apriori diretamente no df, sem a 
# etapa de transformação em lista de transações

itemsets_freq = apriori(df_papa, min_support=0.1, use_colnames=True)
print(itemsets_freq.sort_values(by=['support'], ascending=False))
# Out:
#      support                                           itemsets
# 4   0.731803                                (Lapapaeseconomica)
# 9   0.609612                                            (ARROZ)
# 8   0.555225                                            (CARNE)
# 33  0.440174                         (Lapapaeseconomica, ARROZ)
# 3   0.428578                                    (Lapapaengorda)
# 32  0.406919                         (Lapapaeseconomica, CARNE)
# 5   0.402559                                             (Sopa)
# 43  0.399300                                     (CARNE, ARROZ)
# 0   0.387321                                               (TV)
# 24  0.302458                 (Lapapaengorda, Lapapaeseconomica)
# 68  0.289664                  (Lapapaeseconomica, CARNE, ARROZ)
# 29  0.287508                          (Lapapaeseconomica, Sopa)
# 15  0.285974                            (Lapapaeseconomica, TV)
# 1   0.279266                                (Lapapaessaludable)
# 37  0.269107                                      (ARROZ, Sopa)
# 27  0.266711                             (Lapapaengorda, ARROZ)
# 12  0.262830                            (Lapapaessaludable, TV)
# 10  0.245196                                         (ENSALADA)
# 26  0.238248                             (Lapapaengorda, CARNE)
# 36  0.227754                                      (CARNE, Sopa)
# 18  0.221812                                        (ARROZ, TV)
# 11  0.221669                                            (OTROS)
# 17  0.217308                                        (CARNE, TV)
# 20  0.207485             (Lapapaeseconomica, Lapapaessaludable)
# 45  0.205041                                  (ARROZ, ENSALADA)
# 48  0.192582         (Lapapaeseconomica, Lapapaessaludable, TV)
# 67  0.190713                   (Lapapaeseconomica, ARROZ, Sopa)
# 6   0.190043                                           (Fritas)
# 62  0.186640          (Lapapaengorda, Lapapaeseconomica, ARROZ)
# 71  0.179932                               (CARNE, ARROZ, Sopa)
# 25  0.179309                              (Lapapaengorda, Sopa)
# 65  0.176674                      (Lapapaengorda, CARNE, ARROZ)
# 44  0.172313                                  (CARNE, ENSALADA)
# 34  0.172025                      (Lapapaeseconomica, ENSALADA)
# 61  0.166132          (Lapapaengorda, Lapapaeseconomica, CARNE)
# 66  0.163832                   (Lapapaeseconomica, CARNE, Sopa)
# 54  0.163017                     (Lapapaeseconomica, CARNE, TV)
# 7   0.162298                                           (Sudada)
# 35  0.160334                         (Lapapaeseconomica, OTROS)
# 23  0.160142                         (Lapapaessaludable, ARROZ)
# 55  0.159375                     (Lapapaeseconomica, ARROZ, TV)
# 22  0.156979                         (Lapapaessaludable, CARNE)
# 16  0.155015                                         (TV, Sopa)
# 73  0.152571                           (CARNE, ARROZ, ENSALADA)
# 51  0.151756                     (Lapapaessaludable, ARROZ, TV)
# 14  0.150223                                (Lapapaengorda, TV)
# 50  0.150031                     (Lapapaessaludable, CARNE, TV)
# 56  0.146198                                 (CARNE, ARROZ, TV)
# 70  0.143418               (Lapapaeseconomica, ARROZ, ENSALADA)
# 30  0.135129                        (Lapapaeseconomica, Fritas)
# 78  0.127606            (Lapapaeseconomica, CARNE, ARROZ, Sopa)
# 60  0.125114           (Lapapaengorda, Lapapaeseconomica, Sopa)
# 2   0.123820                                  (Lapapadaenergia)
# 69  0.121951               (Lapapaeseconomica, CARNE, ENSALADA)
# 77  0.121089   (Lapapaengorda, Lapapaeseconomica, CARNE, ARROZ)
# 13  0.120130                              (Lapapadaenergia, TV)
# 46  0.119459                                     (ARROZ, OTROS)
# 40  0.119076                                    (ARROZ, Fritas)
# 57  0.118693      (Lapapaeseconomica, Lapapaessaludable, CARNE)
# 64  0.117447                       (Lapapaengorda, ARROZ, Sopa)
# 42  0.116584                                    (Sudada, ARROZ)
# 31  0.116201                        (Lapapaeseconomica, Sudada)
# 58  0.115195      (Lapapaeseconomica, Lapapaessaludable, ARROZ)
# 21  0.113757                          (Lapapaessaludable, Sopa)
# 74  0.112368  (Lapapaeseconomica, Lapapaessaludable, CARNE, TV)
# 41  0.112368                                    (Sudada, CARNE)
# 38  0.112128                                   (Sopa, ENSALADA)
# 53  0.111984                      (Lapapaeseconomica, TV, Sopa)
# 28  0.110690                          (Lapapaengorda, ENSALADA)
# 79  0.108918        (Lapapaeseconomica, CARNE, ARROZ, ENSALADA)
# 49  0.108103                      (Lapapaessaludable, TV, Sopa)
# 52  0.108007             (Lapapaengorda, Lapapaeseconomica, TV)
# 75  0.107528  (Lapapaeseconomica, Lapapaessaludable, ARROZ, TV)
# 19  0.107192                 (Lapapaengorda, Lapapaessaludable)
# 76  0.106378              (Lapapaeseconomica, CARNE, ARROZ, TV)
# 39  0.104701                                    (CARNE, Fritas)
# 59  0.104030                  (Lapapaessaludable, CARNE, ARROZ)
# 47  0.103790             (Lapapaengorda, Lapapaessaludable, TV)
# 72  0.101730                            (ARROZ, Sopa, ENSALADA)
# 63  0.100819                       (Lapapaengorda, CARNE, Sopa)

# %% [markdown]
# #### Obtenção das Regras de Associação

# %%
# Obtém as regras de associação a partir dos itemsets mais frequentes. 
# Como sugerido no exercício, filtramos para os casos com confiança mínima de 50%

regras = association_rules(itemsets_freq, metric="confidence", min_threshold=0.5)


#Ordena as Regras por confiança
regrasOrdenadas = regras.sort_values('confidence' , ascending=False)

# %%
regrasOrdenadas.head()
# Out:
#                            antecedents consequents  antecedent support  \
# 2                    (Lapapadaenergia)        (TV)            0.123820
# 32  (Lapapaengorda, Lapapaessaludable)        (TV)            0.107192
# 40          (Lapapaessaludable, CARNE)        (TV)            0.156979
# 38           (Lapapaessaludable, Sopa)        (TV)            0.113757
# 44          (Lapapaessaludable, ARROZ)        (TV)            0.160142
#
#     consequent support   support  confidence      lift  leverage  conviction
# 2             0.387321  0.120130    0.970201  2.504903  0.072172   20.560556
# 32            0.387321  0.103790    0.968261  2.499894  0.062272   19.303706
# 40            0.387321  0.150031    0.955739  2.467563  0.089230   13.842322
# 38            0.387321  0.108103    0.950295  2.453508  0.064042   12.326273
# 44            0.387321  0.151756    0.947636  2.446643  0.089730   11.700420

# %%
# mantendo somente as colunas de interesse
regrasOrden = regrasOrdenadas[['antecedents', 'consequents', 'support', 'confidence']]

# %%
regrasOrden.head()
# Out:
#                            antecedents consequents   support  confidence
# 2                    (Lapapadaenergia)        (TV)  0.120130    0.970201
# 32  (Lapapaengorda, Lapapaessaludable)        (TV)  0.103790    0.968261
# 40          (Lapapaessaludable, CARNE)        (TV)  0.150031    0.955739
# 38           (Lapapaessaludable, Sopa)        (TV)  0.108103    0.950295
# 44          (Lapapaessaludable, ARROZ)        (TV)  0.151756    0.947636

# %% [markdown]
# ## Análise das Regras de Associação

# %% [markdown]
# Como vimos anteriormente, os casos em 'Sim' são muito mais raros e, portanto, os casos de maior interesse.
# Portanto, vamos focar a análise nas regras relacionadas ao questionamento de quando a batata engorda.

# %% [markdown]
# **Vamos portanto entender: o que ocorre quando quando as pessoas acreditam que a batata engorda?**

# %%
# criando lista com índices de interesse
filtro = []
for index, row in regrasOrden.iterrows():
    for ent in row['antecedents']:
        if ent == 'Lapapaengorda':
            filtro.append(index)
            break

# %%
regrasOrden.loc[regrasOrden.index.isin(filtro), : ][['antecedents','consequents','confidence', 'support']]
# Out:
#                                    antecedents                 consequents  \
# 32          (Lapapaengorda, Lapapaessaludable)                        (TV)
# 69                      (Lapapaengorda, CARNE)                     (ARROZ)
# 106  (Lapapaengorda, Lapapaeseconomica, CARNE)                     (ARROZ)
# 48                         (Lapapaengorda, TV)         (Lapapaeseconomica)
# 9                              (Lapapaengorda)         (Lapapaeseconomica)
# 66                      (Lapapaengorda, ARROZ)         (Lapapaeseconomica)
# 62                       (Lapapaengorda, Sopa)         (Lapapaeseconomica)
# 64                      (Lapapaengorda, CARNE)         (Lapapaeseconomica)
# 33                         (Lapapaengorda, TV)         (Lapapaessaludable)
# 108              (Lapapaengorda, CARNE, ARROZ)         (Lapapaeseconomica)
# 70                      (Lapapaengorda, ARROZ)                     (CARNE)
# 68                       (Lapapaengorda, Sopa)                     (ARROZ)
# 107  (Lapapaengorda, Lapapaeseconomica, ARROZ)                     (CARNE)
# 11                             (Lapapaengorda)                     (ARROZ)
# 65          (Lapapaengorda, Lapapaeseconomica)                     (ARROZ)
# 67                       (Lapapaengorda, Sopa)                     (CARNE)
# 10                             (Lapapaengorda)                     (CARNE)
# 63          (Lapapaengorda, Lapapaeseconomica)                     (CARNE)
# 109                     (Lapapaengorda, CARNE)  (Lapapaeseconomica, ARROZ)
#
#      confidence   support
# 32     0.968261  0.103790
# 69     0.741553  0.176674
# 106    0.728872  0.121089
# 48     0.718979  0.108007
# 9      0.705725  0.302458
# 66     0.699784  0.186640
# 62     0.697755  0.125114
# 64     0.697305  0.166132
# 33     0.690909  0.103790
# 108    0.685381  0.121089
# 70     0.662415  0.176674
# 68     0.654997  0.117447
# 107    0.648780  0.121089
# 11     0.622317  0.266711
# 65     0.617079  0.186640
# 67     0.562266  0.100819
# 10     0.555903  0.238248
# 63     0.549271  0.166132
# 109    0.508246  0.121089

# %% [markdown]
# - O primeiro *insight* otido é que 97% pessoas que pensam que a batata engorda e é saudável viram propaganda na TV
# - Um outro ponto interessasnte é sobre o consumo: 74% das pessoas que pensam que a batata engorda e a comem com carne usam o acompanhamento arroz, assim como as pessoas que pensam que engorda, que é econômica e a comem com carne (73%). Se mirarmos no caso exclusivo das pessoas que pensam que a batata engorda, 56% a usam com carne como acompanhamento
# - Também é interessante notar que 69% das pessoas que pensam que a batata engorda E que viram propaganda na TV pensam que a batata é saudável

# %% [markdown]
# **Vamos agora entender a outra situação: quais casos normalmente ocorrem que levam as pessoas a pensar que a batata engorda?**

# %%
# criando lista com índices de interesse
filtro = []
for index, row in regrasOrden.iterrows():
    for ent in row['consequents']:
        if ent == 'Lapapaengorda':
            filtro.append(index)
            break

# %%
regrasOrden.loc[regrasOrden.index.isin(filtro), : ][['antecedents','consequents','confidence', 'support']]
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, confidence, support]
# Index: []

# %% [markdown]
# - Vemos que não há nenhum caso de interesse nesta situação, por um dos dois fatores: ou a frequência mínima não atingiu 10% dos casos ou o suporte não chegou a 50%. Em ambos os casos, de fato não há itens de interesse, e os principais *insights* estão na análise anterior!
